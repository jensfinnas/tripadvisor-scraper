# %%
# %matplotlib inline
import dataset
import pandas as pd

# %%
# Get data
db_url = "sqlite:///data/tripadvisor.db"
db = dataset.connect(db_url)
attractions = db["attractions"]

df = pd.DataFrame([row for row in attractions.all()])

# %%
# Add county where missing
gotland_places = [u'Dalhem', u'Tofta', u'Visby', u'Fårö', u'Gotland', u'Fårösund', u'Klintehamn', u'Burgsvik', u'Rydal', u'Roma',
       u'Tingst\xe4de', u'Västergarn']
kalmar_places = [u'Öland', u'Byxelkrok', u'Borgholm', u'Färjestaden', u'Löttorp', u'Mörbylånga']
vasternorrland_places = [u'Örnsköldsvik',u'Ulvöhamn']

df.loc[df.city.isin(gotland_places), 'county'] = 'Gotland'
df.loc[df.city.isin(kalmar_places), 'county'] = u'Kalmar län'
df.loc[df.city.isin(vasternorrland_places), 'county'] = u'Västernorrlands län'

# %%
# Cleaning

# Remove arrow from county name
df['county'] = df.loc[:, 'county'].str.replace(u"›","")

# %%
def get_score(x):
    score = 0
    for points, perc in enumerate(x):
        score += (points + 1) * perc
    return score

# %%
grade_cols = [u'Dåligt', u'Hemskt', u'Medelmåttigt', u'Mycket bra', u'Utmärkt']
grade_cols_perc = ["%s (%%)" % x for x in grade_cols]

# Count percentages
_df = df[grade_cols].apply(lambda x: x / x.sum(), axis=1)
_df.columns = grade_cols_perc
df = df.join(_df)

# Count score
df[u"Poäng"] = df[grade_cols_perc].apply(get_score, axis=1)

# Add column with total number of reviews
df["Antal recensioner"] = df[grade_cols].sum(axis=1)

# Remove attractions with few reviews
LIMIT = 10
df_filt = df[df["Antal recensioner"] > LIMIT]

print "Removed attractions with fewer than %s reviews. From %s to %s rows." % (LIMIT, len(df), len(df_filt))
# Out:
# Removed attractions with fewer than 10 reviews. From 2033 to 470 rows.

# %% [markdown]
# ### Vilket län har hetast attraktioner?
#
# När vi räknar ut ett medelpoäng för alla attraktioner som fått minst tio recensioner ser topplistan ut så här.

# %%
# Out:
#                       Dåligt (%)  Hemskt (%)  Medelmåttigt (%)  \
# county
# Bohuslän                0.000000    0.000000          0.000000
# Västerbottens län       0.002119    0.000000          0.094807
# Jönköpings län          0.032341    0.000000          0.069434
# Värmlands län           0.002439    0.016333          0.120607
# Västmanlands län        0.014457    0.010973          0.103806
# Östergötlands län       0.014263    0.006187          0.100621
# Gotland                 0.011771    0.012784          0.103970
# Gävleborgs län          0.020440    0.022222          0.082525
# Norrbottens län         0.023713    0.021157          0.097905
# Blekinge län            0.013051    0.007407          0.077916
# Västernorrlands län     0.018381    0.003788          0.090006
# Kronobergs län          0.017045    0.010417          0.133034
# Skåne län               0.031797    0.013095          0.102407
# Västra Götalands län    0.015927    0.009588          0.124303
# Dalarnas län            0.037191    0.001681          0.109478
# Hallands län            0.029836    0.017932          0.111784
# Jämtlands län           0.000000    0.000000          0.127630
# Kalmar län              0.036553    0.028791          0.108508
# Södermanlands län       0.035677    0.016845          0.138437
# Örebro län              0.042184    0.008383          0.119883
# Uppsala län             0.031095    0.027269          0.151008
# Stockholms län          0.045794    0.019924          0.128036
#
#                       Mycket bra (%)  Utmärkt (%)  Antal attraktioner  \
# county
# Bohuslän                    0.200000     0.800000                   1
# Västerbottens län           0.386952     0.516122                   8
# Jönköpings län              0.338150     0.560075                  13
# Värmlands län               0.335422     0.525199                  10
# Västmanlands län            0.373899     0.496865                  11
# Östergötlands län           0.397787     0.481142                  26
# Gotland                     0.385260     0.486215                  12
# Gävleborgs län              0.367900     0.506912                  12
# Norrbottens län             0.355280     0.501945                  17
# Blekinge län                0.504430     0.397195                   9
# Västernorrlands län         0.469874     0.417951                  11
# Kronobergs län              0.376665     0.462839                   8
# Skåne län                   0.375020     0.477681                  76
# Västra Götalands län        0.415806     0.434376                  76
# Dalarnas län                0.400207     0.451443                  17
# Hallands län                0.395707     0.444741                  15
# Jämtlands län               0.556287     0.316083                   6
# Kalmar län                  0.388004     0.438144                  16
# Södermanlands län           0.373208     0.435834                  15
# Örebro län                  0.453228     0.376323                   8
# Uppsala län                 0.384813     0.405815                  14
# Stockholms län              0.408440     0.397806                  89
#
#                          Poäng
# county
# Bohuslän              4.800000
# Västerbottens län     4.414959
# Jönköpings län        4.393617
# Värmlands län         4.364608
# Västmanlands län      4.327740
# Östergötlands län     4.325358
# Gotland               4.321364
# Gävleborgs län        4.318623
# Norrbottens län       4.290588
# Blekinge län          4.265310
# Västernorrlands län   4.265224
# Kronobergs län        4.257836
# Skåne län             4.253692
# Västra Götalands län  4.243115
# Dalarnas län          4.227030
# Hallands län          4.207585
# Jämtlands län         4.188452
# Kalmar län            4.162395
# Södermanlands län     4.156677
# Örebro län            4.113123
# Uppsala län           4.106984
# Stockholms län        4.092538

# %% [markdown]
# Vi kan strunta i Bohuslän som bara har en attraktion med här. Då är **Västerbotten**, **Jönköping** och **Värmland** de län vars besöksmål får högst betyg på Tripadvisor.
#
# Vilka attraktioner är då det?

# %%
columns_to_include = ["city","name", u"Poäng", "Antal recensioner"]
df_filt[df_filt.county == u"Västerbottens län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#           city                           name     Poäng  Antal recensioner
# 1734   Vindeln     Aurora Borealis Adventures  5.000000                 13
# 958       Umeå             Guitars the Museum  4.576271                 59
# 960       Umeå                     Bildmuseet  4.516129                 31
# 31    Markaryd  Smålandet Markaryds Älgsafari  4.500000                 16
# 961       Umeå              Umedalen Skulptur  4.428571                 21

# %%
df_filt[df_filt.county == u"Jönköpings län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#            city                                   name     Poäng  \
# 877   Jönköping            Tur & Natur - Nystedt Husky  4.954545
# 2025  Ramkvilla                Ramoa Adventure Village  4.920000
# 1064     Gränna                          Polkapojkarna  4.911765
# 879   Jönköping                             Habo Kyrka  4.826087
# 1470      Eksjö  Naturreservatet Skurugata & Skuruhatt  4.583333
#
#       Antal recensioner
# 877                  22
# 2025                 50
# 1064                 34
# 879                  23
# 1470                 12

# %%
df_filt[df_filt.county == u"Värmlands län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#            city                    name     Poäng  Antal recensioner
# 850   Karlsborg  Tivedens National park  4.846154                 13
# 1530   Ekshärad    Värmlands Moose Park  4.833333                 18
# 780    Karlstad    Sandgrund Lars Lerin  4.548780                 82
# 851   Karlsborg     Karlsborgs Fästning  4.476190                 21
# 779    Karlstad        Mariebergsskogen  4.454545                 66

# %% [markdown]
# ## Vilken stad har hetast attraktioner?
#
# Vi räknar medelbetyget på attrakioner i varje stad och inkluderar bara städer som har minst fem attraktioner
#
# **Visby**, **Lund** och **Borås** i topp!

# %%
# Get mean reviews
avg_reviews = df_filt.groupby("city").mean()[grade_cols_perc]

# Get scores
avg_reviews[u"Poäng"] = avg_reviews[grade_cols_perc].apply(get_score, axis=1)

# Get number of attraktions
avg_reviews["Antal attraktioner"] = df_filt.groupby("city").count()["id"]

# Filter cities with few attractions
avg_reviews[avg_reviews["Antal attraktioner"] > 5].sort_values(u"Poäng", ascending=False)
# Out:
#              Dåligt (%)  Hemskt (%)  Medelmåttigt (%)  Mycket bra (%)  \
# city
# Visby          0.006293    0.000000          0.100162        0.379658
# Lund           0.030380    0.000000          0.071328        0.414394
# Borås          0.044901    0.000000          0.082538        0.339397
# Jönköping      0.051282    0.000000          0.079362        0.346107
# Norrköping     0.017292    0.000000          0.122884        0.403515
# Sundsvall      0.033699    0.006944          0.089116        0.418141
# Västerås       0.016830    0.015088          0.135055        0.394418
# Växjö          0.015152    0.013889          0.162227        0.353230
# Gävle          0.030660    0.033333          0.097154        0.414421
# Uppsala        0.023148    0.007407          0.154042        0.437016
# Eskilstuna     0.030403    0.027693          0.153272        0.354691
# Göteborg       0.020400    0.013014          0.163093        0.419192
# Helsingborg    0.035070    0.028447          0.110659        0.425180
# Stockholm      0.040952    0.016597          0.131191        0.413443
# Halmstad       0.042650    0.018791          0.111534        0.446964
# Örebro         0.037221    0.009580          0.137009        0.452041
# Malmö          0.051762    0.014365          0.141108        0.410033
#
#              Utmärkt (%)     Poäng  Antal attraktioner
# city
# Visby           0.513887  4.394846                   8
# Lund            0.483899  4.321431                   6
# Borås           0.533164  4.315923                   7
# Jönköping       0.523249  4.290041                   6
# Norrköping      0.456309  4.281550                   9
# Sundsvall       0.452100  4.247997                   6
# Västerås        0.438609  4.222888                   8
# Växjö           0.455503  4.220044                   6
# Gävle           0.424431  4.168631                   8
# Uppsala         0.378386  4.140085                  10
# Eskilstuna      0.433941  4.134075                   7
# Göteborg        0.384302  4.133983                  38
# Helsingborg     0.400644  4.127883                  11
# Stockholm       0.397817  4.110577                  69
# Halmstad        0.380062  4.102998                   7
# Örebro          0.364149  4.096316                   7
# Malmö           0.382732  4.057607                  23

# %% [markdown]
# ## Vilken typ av attraktioner får högst betyg?

# %%
# Aggregate scores by tag
tags = {}
        
for row in df[["tags", u"Poäng"]].iterrows():
    score = row[1][1]
    for tag in row[1][0].split("|"):
        if tag not in tags:
            tags[tag] = []
        # Append score
        tags[tag].append(score)

# %%
# Create a dataframe with mean score by tag
by_tag = pd.DataFrame({
    "Medelbetyg": [pd.Series(x).mean() for x in tags.values()],
    "Antal aktiviteter": [len(x) for x in tags.values()],
}, index=tags.keys())

# %% [markdown]
# Vi räknar ut ett medelbetyg för alla aktivitetstyper som förekommer minst fem gånger. **Aktivitet och action** får höga poäng. **Forntida ruiner** är ingen succé.

# %%
by_tag[by_tag["Antal aktiviteter"] > 5].sort_values("Medelbetyg", ascending=False)
# Out:
#                                    Antal aktiviteter  Medelbetyg
# Adrenalin- och extremturer                         9    4.990909
# Cykelturer                                        12    4.982078
# Lektioner och seminarier                           6    4.966667
# Privata rundturer                                  8    4.884354
# Ekoturer                                           7    4.874459
# Kurser och seminarier                             16    4.836797
# Terrängfordonsturer                                9    4.833974
# Zipline och höghöjdsparker                        12    4.829630
# Skogar                                            16    4.812500
# Vandrings- och campingturer                        6    4.791667
# Natur- och vildmarksturer                         29    4.687689
# Idrottsläger och utbildningar                      7    4.674286
# Geologiska formationer                            11    4.655401
# Bondgårdar                                        11    4.654708
# Sightseeing-turer                                 27    4.642234
# Kanot- och kajakpaddling                          22    4.638711
# Nationalparker                                    42    4.570892
# Rundturer                                        156    4.570052
# Golfbanor                                         32    4.555190
# Vandringsleder                                    47    4.536750
# Utkikspunkter                                     15    4.528107
# Skid- och snöturer                                16    4.525000
# Vattensport och rundturer med båt                 47    4.509947
# Pir- och strandpromenader                          8    4.499561
# Spa och välmående                                 25    4.484603
# Natur- och vildmarksområden                      113    4.470066
# Fisketurer och -charter                            9    4.458333
# Vattendrag                                        31    4.438558
# Uthyrning av utrustning                           35    4.423148
# Span                                              21    4.411310
# ...                                              ...         ...
# Skid- och snowboardområden                        23    4.101788
# Sevärdheter och landmärken                       576    4.091915
# Kulturhus                                          7    4.091707
# Vattenfall                                         7    4.087755
# Vetenskapsmuseer                                  10    4.084249
# Trädgårdar                                        34    4.083017
# Temaparker                                        28    4.078767
# Andra rancher och bondgårdar                      11    4.070370
# Fabriksrundturer                                  10    4.054762
# Historiska platser                                76    4.052560
# Resurser för resenärer                            30    4.045963
# Historiska promenadområden                        21    4.039321
# Andra nöjen och aktiviteter                       34    4.032363
# Spel och nöjen                                   111    4.030581
# Broar                                              7    4.025432
# Transport                                         10    3.981713
# Idrottsanläggningar                               13    3.952268
# Lekplatser                                        29    3.950412
# Turistcenter                                      16    3.950000
# Djurparker och akvarier                           27    3.943508
# Gallerior                                         11    3.936305
# Område                                            14    3.934788
# Vatten- och nöjesparker                           47    3.914443
# Andra djurparker och akvarier                      8    3.875601
# Arenor och idrottsarenor                          10    3.863422
# Spelhallar och nöjesplatser                       20    3.811101
# Vattenland                                        21    3.637782
# Fabriksförsäljning                                11    3.634118
# Monument och statyer                              35    3.540763
# Forntida ruiner                                   16    3.424006
#
# [101 rows x 2 columns]
