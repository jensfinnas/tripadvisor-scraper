# %%
# %matplotlib inline
import dataset
import pandas as pd
import matplotlib.pylab as plt

# %%
# Get data
db_url = "sqlite:///data/tripadvisor.db"
db = dataset.connect(db_url)
attractions = db["attractions"]

df = pd.DataFrame([row for row in attractions.all()])

# %%
# Add county where missing
gotland_places = [u'Dalhem', u'Tofta', u'Visby', u'Fårö', u'Gotland', u'Fårösund', u'Klintehamn', u'Burgsvik', u'Rydal', u'Roma',
       u'Tingst\xe4de', u'Västergarn']
kalmar_places = [u'Öland', u'Byxelkrok', u'Borgholm', u'Färjestaden', u'Löttorp', u'Mörbylånga']
vasternorrland_places = [u'Örnsköldsvik',u'Ulvöhamn']

df.loc[df.city.isin(gotland_places), 'county'] = 'Gotland'
df.loc[df.city.isin(kalmar_places), 'county'] = u'Kalmar län'
df.loc[df.city.isin(vasternorrland_places), 'county'] = u'Västernorrlands län'

# %%
# Cleaning

# Remove arrow from county name
df['county'] = df.loc[:, 'county'].str.replace(u"›","")

# %%
def get_score(x):
    score = 0
    for points, perc in enumerate(x):
        score += (points + 1) * perc
    return score

# %%
grade_cols = [u'Dåligt', u'Hemskt', u'Medelmåttigt', u'Mycket bra', u'Utmärkt']
grade_cols_perc = ["%s (%%)" % x for x in grade_cols]

# Count percentages
_df = df[grade_cols].apply(lambda x: x / x.sum(), axis=1)
_df.columns = grade_cols_perc
df = df.join(_df)

# Count score
df[u"Poäng"] = df[grade_cols_perc].apply(get_score, axis=1)

# Add column with total number of reviews
df["Antal recensioner"] = df[grade_cols].sum(axis=1)

# Remove attractions with few reviews
# Attractions with fewer than 5 reviews tend to have a pretty distored score distribution
LIMIT = 5
df_filt = df[df["Antal recensioner"] > LIMIT]

print "Removed attractions with fewer than %s reviews. From %s to %s rows." % (LIMIT, len(df), len(df_filt))
# Out:
# Removed attractions with fewer than 5 reviews. From 2033 to 738 rows.

# %% [markdown]
# ### Vilket län har hetast attraktioner?
#
# När vi räknar ut ett medelpoäng för alla attraktioner som fått minst tio recensioner ser topplistan ut så här.

# %%
by_county = df_filt.groupby("county")[grade_cols_perc].mean()
by_county[u"Poäng"] = by_county.apply(get_score, axis=1)
by_county[u"Antal attraktioner"] = df_filt.groupby("county").count().id
by_county.sort_values(u"Poäng", ascending=False)
# Out:
#                       Dåligt (%)  Hemskt (%)  Medelmåttigt (%)  \
# county
# Bohuslän                0.000000    0.000000          0.000000
# Norrbottens län         0.026734    0.011239          0.066893
# Västerbottens län       0.013317    0.011905          0.093628
# Västernorrlands län     0.010110    0.002083          0.070535
# Gotland                 0.008309    0.015560          0.073390
# Gävleborgs län          0.026067    0.020614          0.092159
# Kronobergs län          0.019944    0.005952          0.129647
# Östergötlands län       0.011238    0.004875          0.119344
# Värmlands län           0.032099    0.011667          0.095076
# Kalmar län              0.018866    0.030989          0.097607
# Skåne län               0.030839    0.009657          0.096880
# Jönköpings län          0.034262    0.013258          0.085979
# Jämtlands län           0.029135    0.006579          0.092831
# Hallands län            0.033925    0.011208          0.111069
# Örebro län              0.032022    0.004471          0.107985
# Västra Götalands län    0.021767    0.012994          0.131525
# Dalarnas län            0.027208    0.000794          0.148534
# Uppsala län             0.028909    0.019088          0.143245
# Blekinge län            0.032200    0.013690          0.117833
# Västmanlands län        0.029631    0.005487          0.159569
# Södermanlands län       0.049234    0.021855          0.135920
# Stockholms län          0.042735    0.024580          0.131647
#
#                       Mycket bra (%)  Utmärkt (%)     Poäng  \
# county
# Bohuslän                    0.385714     0.614286  4.614286
# Norrbottens län             0.296679     0.598454  4.428879
# Västerbottens län           0.338160     0.542990  4.385601
# Västernorrlands län         0.431923     0.485349  4.380318
# Gotland                     0.393797     0.508944  4.379506
# Gävleborgs län              0.354183     0.506976  4.295388
# Kronobergs län              0.354580     0.489876  4.288491
# Östergötlands län           0.415296     0.449248  4.286442
# Värmlands län               0.373601     0.487557  4.272849
# Kalmar län                  0.373327     0.479211  4.263028
# Skåne län                   0.396537     0.466086  4.257376
# Jönköpings län              0.398156     0.468345  4.253064
# Jämtlands län               0.440394     0.431060  4.237665
# Hallands län                0.397714     0.446085  4.210825
# Örebro län                  0.433706     0.421816  4.208824
# Västra Götalands län        0.402544     0.431170  4.208358
# Dalarnas län                0.384589     0.438876  4.207131
# Uppsala län                 0.363179     0.445578  4.177428
# Blekinge län                0.458346     0.377931  4.136118
# Västmanlands län            0.428850     0.376463  4.117027
# Södermanlands län           0.372468     0.420523  4.093192
# Stockholms län              0.423539     0.377498  4.068485
#
#                       Antal attraktioner
# county
# Bohuslän                               2
# Norrbottens län                       32
# Västerbottens län                     12
# Västernorrlands län                   20
# Gotland                               17
# Gävleborgs län                        19
# Kronobergs län                        14
# Östergötlands län                     33
# Värmlands län                         14
# Kalmar län                            31
# Skåne län                            116
# Jönköpings län                        22
# Jämtlands län                         19
# Hallands län                          24
# Örebro län                            15
# Västra Götalands län                 105
# Dalarnas län                          36
# Uppsala län                           20
# Blekinge län                          14
# Västmanlands län                      22
# Södermanlands län                     23
# Stockholms län                       128

# %% [markdown]
# Vi kan strunta i Bohuslän som bara har en attraktion med här. Då är **Västerbotten**, **Jönköping** och **Värmland** de län vars besöksmål får högst betyg på Tripadvisor.
#
# Vilka attraktioner är då det?

# %%
columns_to_include = ["city","name", u"Poäng", "Antal recensioner"]
df_filt[df_filt.county == u"Norrbottens län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#              city                            name  Poäng  Antal recensioner
# 1927       Harads            Pure Lapland - Tours    5.0               10.0
# 1900       Vidsel        Laponie Mush - Day Tours    5.0               16.0
# 1899  Norrfjärden  Svedjekojan in Swedish Lapland    5.0                8.0
# 1434  Jukkasjarvi                     Ice Driving    5.0                7.0
# 1229   Arvidsjaur                    Burning Snow    5.0                9.0

# %%
df_filt[df_filt.county == u"Västerbottens län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#             city                            name     Poäng  Antal recensioner
# 1690  Vilhelmina  Wilderness Latitude - Day Tour  5.000000                9.0
# 1734     Vindeln      Aurora Borealis Adventures  5.000000               13.0
# 1689  Vilhelmina             Fatmomakke Kyrkstad  4.625000                8.0
# 958         Umeå              Guitars the Museum  4.576271               59.0
# 960         Umeå                      Bildmuseet  4.516129               31.0

# %%
df_filt[df_filt.county == u"Västernorrlands län"][columns_to_include].sort_values(u"Poäng", ascending=False).head()
# Out:
#               city                        name     Poäng  Antal recensioner
# 1392       Docksta                 Via Ferrata  4.800000               10.0
# 1262  Örnsköldsvik            Slattdalsskrevan  4.777778                9.0
# 843      Sundsvall  Sundsvall-Timrå Turistbyrå  4.714286                7.0
# 1263  Örnsköldsvik     Världsarvet Höga Kusten  4.666667                6.0
# 1391       Docksta                 Skuleberget  4.500000               28.0

# %% [markdown]
# ## Vilken stad har hetast attraktioner?
#
# Vi räknar medelbetyget på attrakioner i varje stad och inkluderar bara städer som har minst fem attraktioner.

# %%
# Get mean reviews
avg_reviews = df_filt.groupby("city").mean()[grade_cols_perc]

# Get scores
avg_reviews[u"Poäng"] = avg_reviews[grade_cols_perc].apply(get_score, axis=1)

# Get number of attraktions
avg_reviews["Antal attraktioner"] = df_filt.groupby("city").count()["id"]

# Filter cities with few attractions
avg_reviews[avg_reviews["Antal attraktioner"] > 5].sort_values(u"Poäng", ascending=False)
# Out:
#              Dåligt (%)  Hemskt (%)  Medelmåttigt (%)  Mycket bra (%)  \
# city
# Ängelholm      0.000000    0.000000          0.049325        0.332313
# Vimmerby       0.003086    0.000000          0.093474        0.311596
# Luleå          0.003247    0.000000          0.079004        0.371985
# Varberg        0.016667    0.013889          0.083333        0.303704
# Visby          0.005034    0.011111          0.080130        0.416425
# Borås          0.044901    0.000000          0.082538        0.339397
# Sundsvall      0.028885    0.005952          0.076385        0.399222
# Norrköping     0.015563    0.000000          0.124881        0.406021
# Linköping      0.002551    0.010417          0.106574        0.477556
# Lund           0.032514    0.000000          0.088035        0.434351
# Ystad          0.045139    0.000000          0.090012        0.387248
# Borlänge       0.009524    0.000000          0.181570        0.365040
# Växjö          0.011364    0.010417          0.175241        0.354208
# Kalmar         0.001553    0.071429          0.083581        0.413706
# Uppsala        0.016534    0.005291          0.153454        0.425760
# Halmstad       0.044283    0.014615          0.086748        0.434940
# Gävle          0.037028    0.026667          0.100223        0.411537
# Eskilstuna     0.026602    0.024231          0.134113        0.397855
# Östersund      0.061224    0.000000          0.114733        0.371308
# Öland          0.031548    0.022619          0.105278        0.445397
# Göteborg       0.021671    0.025116          0.143278        0.408852
# Karlstad       0.054065    0.013889          0.111575        0.386844
# Helsingborg    0.035070    0.028447          0.110659        0.425180
# Jönköping      0.080128    0.000000          0.092855        0.380414
# Karlskrona     0.016601    0.000000          0.140203        0.546739
# Örebro         0.036673    0.006096          0.134265        0.475433
# Stockholm      0.041166    0.020677          0.135571        0.435764
# Malmö          0.048716    0.011393          0.142223        0.443288
# Västerås       0.036912    0.007100          0.180012        0.462709
# Solna          0.060534    0.089467          0.100624        0.485160
#
#              Utmärkt (%)     Poäng  Antal attraktioner
# city
# Ängelholm       0.618363  4.569038                   6
# Vimmerby        0.591843  4.489109                   6
# Luleå           0.545764  4.457019                   7
# Varberg         0.582407  4.421296                   6
# Visby           0.487300  4.369845                  10
# Borås           0.533164  4.315923                   7
# Sundsvall       0.489555  4.314609                   7
# Norrköping      0.453536  4.281966                  10
# Linköping       0.402902  4.267841                   8
# Lund            0.445101  4.259525                  10
# Ystad           0.477601  4.252173                   8
# Borlänge        0.443866  4.233724                   7
# Växjö           0.448770  4.218604                   8
# Kalmar          0.429731  4.198634                   7
# Uppsala         0.398961  4.185321                  14
# Halmstad        0.419413  4.170586                   9
# Gävle           0.424545  4.159905                  10
# Eskilstuna      0.417198  4.154816                   8
# Östersund       0.452734  4.154328                   7
# Öland           0.395159  4.150000                   7
# Göteborg        0.401082  4.142559                  45
# Karlstad        0.433627  4.132079                   6
# Helsingborg     0.400644  4.127883                  11
# Jönköping       0.446604  4.113364                   8
# Karlskrona      0.296457  4.106452                   6
# Örebro          0.347532  4.091054                  11
# Stockholm       0.366822  4.066398                  93
# Malmö           0.354381  4.043226                  29
# Västerås        0.313267  4.008320                  17
# Solna           0.264215  3.803053                   6

# %% [markdown]
# ## Vilken typ av attraktioner får högst betyg?

# %%
# Aggregate scores by tag
tags = {}
        
for row in df_filt[["tags", u"Poäng"]].iterrows():
    score = row[1][1]
    for tag in row[1][0].split("|"):
        if tag not in tags:
            tags[tag] = []
        # Append score
        tags[tag].append(score)

# %%
# Create a dataframe with mean score by tag
by_tag = pd.DataFrame({
    "Medelbetyg": [pd.Series(x).mean() for x in tags.values()],
    "Antal aktiviteter": [len(x) for x in tags.values()],
}, index=tags.keys())

# %% [markdown]
# Vi räknar ut ett medelbetyg för alla aktivitetstyper som förekommer minst fem gånger.

# %%
by_tag[by_tag["Antal aktiviteter"] > 5].sort_values("Medelbetyg", ascending=False)
# Out:
#                                     Antal aktiviteter  Medelbetyg
# Sightseeing-turer                                   8    4.593370
# Vattensport och rundturer med båt                   6    4.573571
# Rundturer                                          31    4.564725
# Andra friluftsaktiviteter                          38    4.504051
# Natur- och vildmarksområden                        25    4.491434
# Nationalparker                                     13    4.454623
# Öar                                                14    4.407306
# Kyrkor och katedraler                              26    4.394396
# Friluftsaktiviteter                                91    4.375256
# Historiska museer                                  32    4.307848
# Natur och parker                                  154    4.293532
# Mer                                                43    4.293043
# Vattendrag                                         13    4.292099
# Heliga och religiösa platser                       12    4.275263
# Parker                                             41    4.273401
# Trädgårdar                                         19    4.271464
# Militärmuseer                                       9    4.261719
# Historiska promenadområden                          9    4.240940
# Konserter och föreställningar                      11    4.240468
# Specialmuseer                                     136    4.236955
# Museer                                            192    4.231726
# Vetenskapsmuseer                                    6    4.223748
# Museer för barn                                     7    4.222340
# Stränder                                            7    4.219621
# Bibliotek                                           6    4.215081
# Span                                                9    4.212698
# Souvenir- och specialaffärer                       18    4.208261
# Resurser för resenärer                              9    4.206350
# Spa och välmående                                  10    4.202540
# Intressanta platser och landmärken                 82    4.200702
# Slott                                              33    4.191816
# Sevärdheter och landmärken                        237    4.189883
# Skid- och snowboardområden                         12    4.183685
# Arkitektoniska byggnader                           19    4.178673
# Historiska platser                                 41    4.150932
# Teatrar                                             6    4.143056
# Lekplatser                                         10    4.139405
# Konstmuseer                                        15    4.137825
# Andra nöjen och aktiviteter                        12    4.112771
# Temaparker                                         19    4.104037
# Shopping                                           35    4.079860
# Spel och nöjen                                     31    4.041027
# Gallerior                                           7    3.935623
# Djurparker och akvarier                            22    3.907942
# Vatten- och nöjesparker                            28    3.904919
# Område                                             10    3.865224
# Andra djurparker och akvarier                       7    3.857830
# Arenor och idrottsarenor                            7    3.757270
# Mat och dryck                                       7    3.656678
# Vattenland                                         10    3.564674

# %% [markdown]
# ## Vilka aktiviteter karaktäriserar länen?

# %%
# Get a list of tags for every county
counties = {}
        
for row in df_filt[["tags", "county", u"Poäng"]].iterrows():
    county = row[1][1]
    score = row[1][2]
    for tag in row[1][0].split("|"):
        if county not in counties:
            counties[county] = []
        # Append score
        counties[county].append((tag, score))

# %% [markdown]
# Vilka är de vanligaste aktivitetstyperna i varje län?

# %%
# Print  list of the 
for county, _tags in counties.iteritems():
    _df = pd.DataFrame({
            "tag": [x[0] for x in _tags],
            u"Poäng": [x[1] for x in _tags],
        })
    
    tags = _df.groupby("tag").mean()
    tags["Antal aktiviteter"] = _df.groupby("tag").count()

    print county
    print "==================="
    print tags.sort_values("Antal aktiviteter", ascending=False).head(10)
    print "\n\n"
# Out:
# Skåne län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.127923                 43
# Museer                              4.306545                 29
# Natur och parker                    4.447673                 25
# Specialmuseer                       4.325523                 21
# Intressanta platser och landmärken  4.081162                 19
# Friluftsaktiviteter                 4.584292                 15
# Mer                                 4.391768                  8
# Slott                               4.370234                  7
# Parker                              4.328548                  7
# Natur- och vildmarksområden         4.584187                  5
#
#
#
# Västernorrlands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Natur och parker                    4.428275                  4
# Friluftsaktiviteter                 4.439316                  4
# Sevärdheter och landmärken          4.524115                  4
# Museer                              4.305556                  3
# Spel och nöjen                      4.248893                  3
# Intressanta platser och landmärken  4.619658                  2
# Andra friluftsaktiviteter           4.256410                  2
# Turistcenter                        4.000000                  1
# Temaparker                          4.166667                  1
# Spelhallar och nöjesplatser         4.285714                  1
#
#
#
# Dalarnas län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.288564                 12
# Museer                              4.280841                  9
# Friluftsaktiviteter                 4.107250                  7
# Natur och parker                    3.952942                  7
# Specialmuseer                       4.284119                  6
# Intressanta platser och landmärken  4.254089                  5
# Skid- och snowboardområden          3.857293                  5
# Vatten- och nöjesparker             4.095238                  3
# Spel och nöjen                      4.216321                  3
# Andra friluftsaktiviteter           4.732143                  2
#
#
#
# Östergötlands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Natur och parker                    4.220719                 12
# Museer                              4.323071                 10
# Sevärdheter och landmärken          4.431575                  8
# Friluftsaktiviteter                 4.459229                  6
# Specialmuseer                       4.204067                  6
# Spel och nöjen                      3.974696                  3
# Museer för barn                     4.406466                  3
# Mer                                 4.483659                  3
# Slott                               4.383927                  3
# Intressanta platser och landmärken  4.400307                  3
#
#
#
# Norrbottens län
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken  4.299237                  6
# Rundturer                   4.718809                  6
# Museer                      4.372238                  5
# Friluftsaktiviteter         4.863636                  5
# Andra friluftsaktiviteter   4.909091                  4
# Specialmuseer               4.356602                  4
# Sightseeing-turer           4.613928                  4
# Vatten- och nöjesparker     3.591257                  3
# Natur och parker            4.285474                  3
# Spel och nöjen              4.291667                  2
#
#
#
# Uppsala län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.091064                 10
# Specialmuseer                       4.156738                  9
# Sevärdheter och landmärken          4.183081                  8
# Mer                                 4.025000                  3
# Historiska platser                  3.997475                  3
# Natur och parker                    4.525000                  3
# Slott                               4.103571                  2
# Natur- och vildmarksområden         4.662500                  2
# Trädgårdar                          4.287500                  2
# Intressanta platser och landmärken  4.521429                  2
#
#
#
# Södermanlands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.319225                  7
# Sevärdheter och landmärken          4.040909                  6
# Natur och parker                    4.129698                  5
# Specialmuseer                       4.433644                  4
# Historiska museer                   4.285714                  3
# Intressanta platser och landmärken  3.904040                  3
# Rundturer                           3.932692                  2
# Friluftsaktiviteter                 3.468137                  2
# Vattendrag                          4.156109                  2
# Militärmuseer                       4.321429                  2
#
#
#
# Stockholms län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.056441                 50
# Museer                              4.143499                 43
# Specialmuseer                       4.165859                 26
# Natur och parker                    4.196160                 25
# Mer                                 4.205558                 12
# Parker                              4.129406                 11
# Historiska museer                   4.241758                 11
# Historiska platser                  4.166047                 11
# Intressanta platser och landmärken  3.971904                  9
# Shopping                            3.828565                  8
#
#
#
# Gävleborgs län
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter         4.394476                  6
# Sevärdheter och landmärken  4.334769                  4
# Specialmuseer               4.508951                  4
# Natur och parker            4.481910                  4
# Museer                      4.508951                  4
# Rundturer                   4.494444                  3
# Vatten- och nöjesparker     3.673652                  3
# Skid- och snowboardområden  4.363636                  2
# Mer                         4.450000                  2
# Andra friluftsaktiviteter   4.041667                  2
#
#
#
# Örebro län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.184780                  5
# Museer                              4.403166                  4
# Natur och parker                    4.234127                  3
# Specialmuseer                       4.237554                  3
# Kyrkor och katedraler               4.357143                  2
# Parker                              4.226190                  2
# Intressanta platser och landmärken  4.142544                  2
# Spel och nöjen                      4.240385                  2
# Souvenir- och specialaffärer        4.000000                  1
# Vatten- och nöjesparker             3.662651                  1
#
#
#
# Jönköpings län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.286109                  6
# Museer                              4.010963                  5
# Specialmuseer                       4.010963                  5
# Natur och parker                    4.484861                  4
# Kyrkor och katedraler               4.481247                  4
# Friluftsaktiviteter                 4.902626                  3
# Cykelturer                          4.937273                  2
# Intressanta platser och landmärken  3.895833                  2
# Mer                                 4.937273                  2
# Andra nöjen och aktiviteter         3.500000                  2
#
#
#
# Värmlands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.330007                  6
# Andra friluftsaktiviteter           4.133333                  3
# Friluftsaktiviteter                 4.133333                  3
# Intressanta platser och landmärken  4.627371                  3
# Museer                              4.046382                  3
# Historiska platser                  4.068966                  2
# Specialmuseer                       3.941667                  2
# Historiska museer                   4.255814                  1
# Monument och statyer                3.960000                  1
# Nationalparker                      4.846154                  1
#
#
#
# Hallands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.137302                  6
# Museer                              4.160453                  4
# Specialmuseer                       4.160453                  4
# Friluftsaktiviteter                 4.582860                  4
# Vatten- och nöjesparker             3.835512                  3
# Shopping                            4.092472                  3
# Natur och parker                    4.386448                  3
# Andra friluftsaktiviteter           4.605850                  3
# Intressanta platser och landmärken  4.301587                  3
# Slott                               3.845238                  2
#
#
#
# Kalmar län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.253753                 15
# Museer                              4.265073                  8
# Specialmuseer                       4.429101                  6
# Natur och parker                    4.007342                  5
# Intressanta platser och landmärken  4.191277                  5
# Friluftsaktiviteter                 4.124961                  5
# Andra friluftsaktiviteter           4.605556                  3
# Historiska platser                  4.273292                  3
# Djurparker och akvarier             3.404070                  2
# Slott                               4.170652                  2
#
#
#
# Jämtlands län
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter          4.153220                 10
# Andra friluftsaktiviteter    4.202457                  6
# Natur och parker             4.144180                  6
# Skid- och snowboardområden   4.629630                  3
# Museer                       4.607993                  3
# Specialmuseer                4.616071                  2
# Vattendrag                   4.000000                  1
# Utsiktsdäck och utsiktstorn  4.222222                  1
# Utkikspunkter                4.222222                  1
# Spel och nöjen               3.909091                  1
#
#
#
# Västmanlands län
# ===================
#                                   Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken     3.989813                  9
# Specialmuseer                  4.126741                  6
# Museer                         4.126741                  6
# Historiska platser             3.827083                  4
# Slott                          3.825000                  2
# Natur och parker               4.209559                  2
# Andra djurparker och akvarier  4.151515                  1
# Rundturer                      4.851852                  1
# Vatten- och nöjesparker        3.916667                  1
# Turistcenter                   4.400000                  1
#
#
#
# Västerbottens län
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter         4.452381                  4
# Natur och parker            4.250000                  4
# Museer                      4.439891                  3
# Sevärdheter och landmärken  4.417413                  3
# Konstmuseer                 4.371701                  2
# Parker                      4.130952                  2
# Arkitektoniska byggnader    4.313620                  2
# Andra friluftsaktiviteter   4.285714                  2
# Specialmuseer               4.401772                  2
# Mer                         4.227273                  1
#
#
#
# Gotland
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Natur och parker                    4.394652                  7
# Sevärdheter och landmärken          4.459889                  4
# Geologiska formationer              4.349537                  3
# Historiska platser                  4.425685                  3
# Intressanta platser och landmärken  4.372159                  2
# Museer                              4.552632                  2
# Specialmuseer                       4.552632                  2
# Friluftsaktiviteter                 4.343750                  2
# Natur- och vildmarksområden         4.540073                  2
# Öar                                 4.750000                  1
#
#
#
# Blekinge län
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken  4.229670                  5
# Natur och parker            4.188690                  4
# Museer                      3.981906                  3
# Öar                         3.966667                  2
# Specialmuseer               3.742424                  2
# Vatten- och nöjesparker     4.181818                  1
# Temaparker                  4.181818                  1
# Span                        3.875000                  1
# Spa och välmående           3.875000                  1
# Slott                       4.076923                  1
#
#
#
# Västra Götalands län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.222259                 31
# Museer                              4.209416                 27
# Natur och parker                    4.360452                 25
# Specialmuseer                       4.207111                 18
# Intressanta platser och landmärken  4.230186                 13
# Shopping                            4.168179                  9
# Friluftsaktiviteter                 4.336980                  8
# Parker                              4.404727                  7
# Natur- och vildmarksområden         4.455439                  6
# Djurparker och akvarier             4.010981                  6
#
#
#
# Bohuslän
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.614286                  2
# Fyrar                               4.428571                  1
# Intressanta platser och landmärken  4.800000                  1
#
#
#
# Kronobergs län
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.133929                  4
# Specialmuseer                       4.130952                  3
# Sevärdheter och landmärken          4.361083                  3
# Rundturer                           4.583333                  2
# Intressanta platser och landmärken  4.390110                  2
# Natur och parker                    4.285714                  2
#                                     3.818182                  1
# Spel och nöjen                      4.954545                  1
# Souvenir- och specialaffärer        3.909091                  1
# Sightseeing-turer                   4.833333                  1

# %% [markdown]
# ## Vilka aktiviteter karakätiersera del olika städerna?

# %%
# Get a list of tags for every county
cities = {}
        
for row in df_filt[["tags", "city", u"Poäng"]].iterrows():
    city = row[1][1]
    score = row[1][2]
    for tag in row[1][0].split("|"):
        if city not in cities:
            cities[city] = []
        # Append score
        cities[city].append((tag, score))

# %%
# Print  list of the 
for city, _tags in cities.iteritems():
    _df = pd.DataFrame({
            "tag": [x[0] for x in _tags],
            u"Poäng": [x[1] for x in _tags],
        })
    
    tags = _df.groupby("tag").mean()
    tags["Antal aktiviteter"] = _df.groupby("tag").count()
    if tags["Antal aktiviteter"].sum() > 10:
        print city
        print "==================="
        print tags.sort_values("Antal aktiviteter", ascending=False).head(10)
        print "\n\n"
# Out:
# Solna
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken  3.774155                  3
# Historiska platser          4.041667                  2
# Arenor och idrottsarenor    3.239130                  1
# Parker                      4.363636                  1
# Span                        3.142857                  1
# Spa och välmående           3.142857                  1
# Slott                       3.750000                  1
# Shopping                    3.989362                  1
# Rundturer                   4.333333                  1
# Natur och parker            4.363636                  1
#
#
#
# Järbo
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter         4.416667                  2
# Andra friluftsaktiviteter   4.833333                  1
# Ekoturer                    4.833333                  1
# Längdskidåkningsområden     4.000000                  1
# Mer                         4.000000                  1
# Natur och parker            4.000000                  1
# Natursköna vägar            4.000000                  1
# Rundturer                   4.833333                  1
# Sevärdheter och landmärken  4.000000                  1
# Skid- och snowboardområden  4.000000                  1
#
#
#
# Eskilstuna
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.244859                  3
# Sevärdheter och landmärken          4.189226                  3
# Specialmuseer                       4.244859                  3
# Intressanta platser och landmärken  4.133838                  2
# Natur och parker                    3.968137                  2
# Djurparker och akvarier             3.686275                  1
# Friluftsaktiviteter                 3.686275                  1
# Heliga och religiösa platser        4.300000                  1
# Parker                              4.250000                  1
#
#
#
# Linköping
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Museer                      4.379503                  4
# Natur och parker            4.177240                  3
# Sevärdheter och landmärken  4.403669                  3
# Museer för barn             4.417391                  2
# Specialmuseer               4.217391                  2
# Trädgårdar                  4.434783                  1
# Spel och nöjen              3.750000                  1
# Slott                       4.111111                  1
# Rundturer                   4.434783                  1
# Parker                      4.346939                  1
#
#
#
# Sundsvall
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.409341                  2
# Spel och nöjen                      4.230482                  2
#                                     4.714286                  1
# Andra nöjen och aktiviteter         4.192308                  1
# Gallerior                           4.208333                  1
# Historiska platser                  4.357143                  1
# Intressanta platser och landmärken  4.461538                  1
# Lekplatser                          4.268657                  1
# Natur och parker                    4.268657                  1
# Resurser för resenärer              4.000000                  1
#
#
#
# Östersund
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter          3.464286                  2
# Museer                       4.724490                  2
# Andra friluftsaktiviteter    4.500000                  1
# Andra nöjen och aktiviteter  3.909091                  1
# Djurparker och akvarier      2.428571                  1
# Historiska museer            4.591837                  1
# Natur och parker             2.428571                  1
# Natursköna tågresor          4.571429                  1
# Rundturer                    4.571429                  1
# Sevärdheter och landmärken   4.222222                  1
#
#
#
# Karlstad
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.194574                  2
# Sevärdheter och landmärken          4.274390                  2
# Andra friluftsaktiviteter           3.400000                  1
# Friluftsaktiviteter                 3.400000                  1
# Historiska museer                   4.255814                  1
# Historiska platser                  4.000000                  1
# Intressanta platser och landmärken  4.548780                  1
# Specialmuseer                       4.133333                  1
# Temaparker                          4.454545                  1
# Vatten- och nöjesparker             4.454545                  1
#
#
#
# Vimmerby
# ===================
#                                  Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken    4.509524                  3
# Andra rancher och bondgårdar  4.550000                  2
# Museer                        4.392857                  2
# Specialmuseer                 4.392857                  2
#                               4.428571                  1
# Bondgårdar                    4.428571                  1
# Historiska platser            4.428571                  1
# Lekplatser                    4.428571                  1
# Mer                           4.428571                  1
# Natur och parker              4.428571                  1
#
#
#
# Borås
# ===================
#                                   Poäng  Antal aktiviteter
# tag
# Museer                         4.417104                  4
# Specialmuseer                  4.263158                  2
# Andra djurparker och akvarier  4.397590                  1
# Andra friluftsaktiviteter      4.600000                  1
# Djurparker och akvarier        4.397590                  1
# Friluftsaktiviteter            4.600000                  1
# Klättringsturer                4.600000                  1
# Konstgallerier                 4.707317                  1
# Kulturhus                      3.545455                  1
# Mer                            4.600000                  1
#
#
#
# Umeå
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Museer                      4.439891                  3
# Arkitektoniska byggnader    4.313620                  2
# Konstmuseer                 4.371701                  2
# Sevärdheter och landmärken  4.313620                  2
# Specialmuseer               4.401772                  2
# Historiska museer           4.227273                  1
# Kaféer                      4.227273                  1
# Mer                         4.227273                  1
# Nattliv                     4.227273                  1
# Natur och parker            4.428571                  1
#
#
#
# Höganäs
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter                 4.900000                  2
# Sevärdheter och landmärken          4.131746                  2
# Intressanta platser och landmärken  4.131746                  2
# Mer                                 4.642857                  2
# Natur och parker                    4.900000                  2
# Uthyrning av utrustning             4.800000                  1
# Stående brädpaddling                4.800000                  1
# Stränder                            5.000000                  1
# Souvenir- och specialaffärer        4.600000                  1
# Shopping                            4.600000                  1
#
#
#
# Öland
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.050000                  5
# Natur och parker                    4.400000                  2
# Historiska platser                  4.000000                  1
# Historiska promenadområden          3.600000                  1
# Intressanta platser och landmärken  4.200000                  1
# Lärorika platser                    4.500000                  1
# Museer                              4.000000                  1
# Nationalparker                      4.333333                  1
# Natur- och vildmarksområden         4.466667                  1
# Parker                              4.333333                  1
#
#
#
# Malmö
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          3.979233                 16
# Intressanta platser och landmärken  3.823708                  7
# Museer                              4.117996                  6
# Specialmuseer                       4.112179                  4
# Natur och parker                    4.321841                  4
# Parker                              4.291867                  3
# Broar                               4.253125                  2
# Arkitektoniska byggnader            4.074720                  2
# Spel och nöjen                      3.357143                  1
# Slott                               3.942857                  1
#
#
#
# Järvsö
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter         4.761174                  3
# Natur och parker            4.691761                  2
# Djurparker och akvarier     4.656250                  1
# Kanot- och kajakpaddling    4.900000                  1
# Kanot- och rappellingturer  4.900000                  1
# Längdskidåkningsområden     4.727273                  1
# Mer                         4.900000                  1
# Rundturer                   4.900000                  1
# Skid- och snowboardområden  4.727273                  1
# Stående brädpaddling        4.900000                  1
#
#
#
# Jönköping
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Andra nöjen och aktiviteter  3.500000                  2
# Kyrkor och katedraler        4.605351                  2
# Museer                       3.708333                  2
# Sevärdheter och landmärken   4.605351                  2
# Specialmuseer                3.708333                  2
# Spel och nöjen               3.500000                  2
# Adrenalin- och extremturer   4.954545                  1
# Cykelturer                   4.954545                  1
# Ekoturer                     4.954545                  1
# Friluftsaktiviteter          4.954545                  1
#
#
#
# Visby
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.459889                  4
# Historiska platser                  4.425685                  3
# Natur och parker                    4.321316                  3
# Intressanta platser och landmärken  4.372159                  2
# Bibliotek                           4.428571                  1
# Grottor                             4.026316                  1
# Kyrkor och katedraler               4.181818                  1
# Mat och dryck                       4.111111                  1
# Mer                                 4.181818                  1
# Museer                              4.355263                  1
#
#
#
# Göteborg
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.094568                 15
# Museer                              4.083770                 13
# Natur och parker                    4.349577                 12
# Specialmuseer                       4.107855                  8
# Parker                              4.390427                  5
# Intressanta platser och landmärken  4.031355                  4
# Historiska platser                  3.775677                  3
# Trädgårdar                          4.387681                  3
# Shopping                            4.048130                  3
# Mer                                 4.183431                  3
#
#
#
# Växjö
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.226190                  3
# Sevärdheter och landmärken          4.113054                  2
# Specialmuseer                       4.267857                  2
#                                     3.818182                  1
# Andra nöjen och aktiviteter         4.954545                  1
# Arkitektoniska byggnader            4.303030                  1
# Heliga och religiösa platser        4.303030                  1
# Historiska museer                   4.142857                  1
# Intressanta platser och landmärken  3.923077                  1
# Natur och parker                    4.071429                  1
#
#
#
# Varberg
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.291667                  2
# Specialmuseer                       4.291667                  2
# Andra friluftsaktiviteter           4.777778                  1
# Friluftsaktiviteter                 4.777778                  1
# Intressanta platser och landmärken  4.333333                  1
# Natur och parker                    4.100000                  1
# Natur- och vildmarksområden         4.100000                  1
# Sevärdheter och landmärken          4.333333                  1
# Spa och välmående                   4.733333                  1
# Span                                4.733333                  1
#
#
#
# Halmstad
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter         4.413194                  2
# Natur och parker            4.529672                  2
# Vatten- och nöjesparker     3.586601                  2
# Andra friluftsaktiviteter   4.312500                  1
# Bibliotek                   4.100000                  1
# Historiska platser          4.228571                  1
# Museer                      3.947368                  1
# Resurser för resenärer      4.100000                  1
# Sevärdheter och landmärken  4.228571                  1
# Shopping                    4.714286                  1
#
#
#
# Luleå
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Friluftsaktiviteter          4.659091                  2
# Spel och nöjen               4.291667                  2
# Andra friluftsaktiviteter    4.636364                  1
# Andra nöjen och aktiviteter  4.166667                  1
# Historiska platser           4.250000                  1
# Museer                       4.714286                  1
# Natur och parker             4.681818                  1
# Sevärdheter och landmärken   4.250000                  1
# Spa och välmående            4.333333                  1
# Span                         4.333333                  1
#
#
#
# Falun
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken  4.465643                  2
# Friluftsaktiviteter         3.571429                  1
# Gruvor                      4.486842                  1
# Historiska platser          4.444444                  1
# Idrottsanläggningar         3.807692                  1
# Museer                      4.000000                  1
# Natur och parker            3.571429                  1
# Skid- och snowboardområden  3.571429                  1
# Specialmuseer               4.000000                  1
# Spel och nöjen              3.807692                  1
#
#
#
# Örebro
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.088118                  4
# Natur och parker                    4.234127                  3
# Intressanta platser och landmärken  4.142544                  2
# Museer                              4.142045                  2
# Parker                              4.226190                  2
# Specialmuseer                       4.142045                  2
# Kyrkor och katedraler               4.142857                  1
# Lekplatser                          4.250000                  1
# Nationalparker                      4.166667                  1
# Shopping                            4.000000                  1
#
#
#
# Uppsala
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Museer                      4.225821                  8
# Specialmuseer               4.329510                  7
# Sevärdheter och landmärken  4.122929                  5
# Mer                         4.025000                  3
# Historiska platser          3.997475                  3
# Natur och parker            4.287500                  2
# Trädgårdar                  4.287500                  2
# Konstmuseer                 3.500000                  1
# Kurser och seminarier       4.571429                  1
# Kyrkor och katedraler       4.222222                  1
#
#
#
# Helsingborg
# ===================
#                                Poäng  Antal aktiviteter
# tag
# Natur och parker            4.419020                  5
# Sevärdheter och landmärken  4.262720                  4
# Trädgårdar                  4.544156                  2
# Djurparker och akvarier     3.926471                  2
# Lekplatser                  4.153846                  1
# Transport                   3.881944                  1
# Teatrar                     3.590909                  1
# Spel och nöjen              4.153846                  1
# Slott                       4.545455                  1
# Parker                      4.333333                  1
#
#
#
# Stockholm
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.021834                 36
# Museer                              4.100873                 32
# Natur och parker                    4.164022                 21
# Specialmuseer                       4.122095                 19
# Parker                              3.989081                  8
# Arkitektoniska byggnader            4.156564                  8
# Historiska museer                   4.151167                  8
# Öar                                 4.419064                  7
# Mer                                 4.160907                  7
# Intressanta platser och landmärken  4.032060                  6
#
#
#
# Trollhättan
# ===================
#                                  Poäng  Antal aktiviteter
# tag
# Museer                        4.195652                  2
# Natur och parker              4.482668                  2
# Specialmuseer                 4.195652                  2
# Lekplatser                    4.411765                  1
# Shopping                      3.250000                  1
# Souvenir- och specialaffärer  3.250000                  1
# Spel och nöjen                4.411765                  1
# Vattendrag                    4.553571                  1
#
#
#
# Tomelilla
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Dalgångar                    4.500000                  1
# Friluftsaktiviteter          4.500000                  1
# Geologiska formationer       4.500000                  1
# Mer                          4.500000                  1
# Museer                       4.750000                  1
# Nationalparker               4.500000                  1
# Natur och parker             4.500000                  1
# Natur- och vildmarksområden  4.500000                  1
# Sevärdheter och landmärken   4.692308                  1
# Slott                        4.692308                  1
#
#
#
# Lund
# ===================
#                                  Poäng  Antal aktiviteter
# tag
# Museer                        4.465251                  4
# Sevärdheter och landmärken    3.923682                  3
# Natur och parker              4.321068                  3
# Heliga och religiösa platser  4.060523                  2
# Historiska museer             4.430502                  2
# Vattendrag                    4.178571                  2
# Trädgårdar                    4.398268                  2
# Mer                           4.370047                  2
# Annan natur och parker        4.190476                  1
# Spel och nöjen                4.190476                  1
#
#
#
# Höör
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Andra djurparker och akvarier       4.280702                  1
# Djurparker och akvarier             4.280702                  1
# Friluftsaktiviteter                 4.280702                  1
# Heliga och religiösa platser        3.875000                  1
# Historiska platser                  3.875000                  1
# Intressanta platser och landmärken  3.875000                  1
# Kyrkor och katedraler               3.875000                  1
# Mer                                 3.875000                  1
# Natur och parker                    4.280702                  1
# Sevärdheter och landmärken          3.875000                  1
#
#
#
# Karlskrona
# ===================
#                                   Poäng  Antal aktiviteter
# tag
# Museer                         3.981906                  3
# Sevärdheter och landmärken     4.230998                  3
# Specialmuseer                  3.742424                  2
# Kyrkor och katedraler          4.187500                  1
# Militärbaser och anläggningar  4.428571                  1
# Militärmuseer                  4.460870                  1
# Slott                          4.076923                  1
#
#
#
# Norrköping
# ===================
#                                 Poäng  Antal aktiviteter
# tag
# Museer                       4.271111                  5
# Natur och parker             4.253133                  3
# Specialmuseer                4.144160                  3
# Spel och nöjen               4.087045                  2
# Andra nöjen och aktiviteter  4.384615                  1
# Vandringsleder               4.684211                  1
# Teatrar                      4.125000                  1
# Sevärdheter och landmärken   4.579710                  1
# Parker                       4.285714                  1
# Museer för barn              4.384615                  1
#
#
#
# Gävle
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.436177                  3
# Sevärdheter och landmärken          4.446359                  3
# Specialmuseer                       4.436177                  3
# Vatten- och nöjesparker             3.328660                  2
# Fabriksrundturer                    3.750000                  1
# Historiska promenadområden          4.296296                  1
# Intressanta platser och landmärken  4.454545                  1
# Mat och dryck                       3.750000                  1
# Matrundturer                        3.750000                  1
# Natur och parker                    4.544118                  1
#
#
#
# Kalmar
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.415661                  4
# Museer                              3.772989                  2
# Bondgårdar                          4.750000                  1
# Broar                               4.146341                  1
# Heliga och religiösa platser        4.375000                  1
# Historiska museer                   4.379310                  1
# Historiska platser                  4.391304                  1
# Intressanta platser och landmärken  4.391304                  1
# Konstmuseer                         3.166667                  1
# Mer                                 4.391304                  1
#
#
#
# Borlänge
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken          4.377778                  3
# Andra rancher och bondgårdar        4.133333                  1
# Friluftsaktiviteter                 4.534483                  1
# Gallerior                           4.111111                  1
# Intressanta platser och landmärken  4.333333                  1
# Kyrkor och katedraler               4.666667                  1
# Museer                              4.000000                  1
# Museer för barn                     4.000000                  1
# Natur och parker                    4.534483                  1
# Shopping                            4.111111                  1
#
#
#
# Västerås
# ===================
#                                   Poäng  Antal aktiviteter
# tag
# Sevärdheter och landmärken     3.936711                  8
# Historiska platser             3.827083                  4
# Specialmuseer                  3.940112                  4
# Museer                         3.940112                  4
# Slott                          3.825000                  2
# Natur och parker               4.209559                  2
# Andra djurparker och akvarier  4.151515                  1
# Resurser för resenärer         4.400000                  1
# Vatten- och nöjesparker        3.916667                  1
# Turistcenter                   4.400000                  1
#
#
#
# Ängelholm
# ===================
#                               Poäng  Antal aktiviteter
# tag
# Andra friluftsaktiviteter  4.651852                  3
# Friluftsaktiviteter        4.651852                  3
# Museer                     4.466624                  2
# Specialmuseer              4.466624                  2
# Klättringsturer            4.733333                  1
# Mer                        4.733333                  1
# Natur och parker           4.525424                  1
# Parker                     4.525424                  1
# Rundturer                  4.733333                  1
# Uthyrning av utrustning    4.888889                  1
#
#
#
# Ystad
# ===================
#                                        Poäng  Antal aktiviteter
# tag
# Museer                              4.113095                  3
# Sevärdheter och landmärken          4.437672                  3
# Specialmuseer                       4.113095                  3
# Intressanta platser och landmärken  4.489842                  2
# Djurparker och akvarier             4.142857                  1
# Friluftsaktiviteter                 4.142857                  1
# Kyrkor och katedraler               4.333333                  1
# Natur och parker                    4.142857                  1
# Spa och välmående                   4.222222                  1
# Span                                4.222222                  1

# %%
# Should we trust activities with few reviews
# Visulize the distribution of scores
bins = [0, 2, 4, 6, 8, 10, 15, 1000]
bins = [0,5,1000]
df["Antal recensioner - grupp"] = pd.cut(df["Antal recensioner"], bins=bins)

df[u"Poäng"].hist(by=df["county"])
